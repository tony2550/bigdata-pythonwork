# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import urllib.request as req

# %%
res=urlopen('https://movie.naver.com/movie/point/af/list.naver')
soup=bs(res,'html.parser')
movie_reviews = soup.select('td.title')
#for review in movie_reviews:
    #print(review.text)

# %%
res2=urlopen('https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC') # 인코딩 16진수 자동으로 됨
soup=bs(res2,'html.parser')
url3='https://ko.wikisource.org'
#print(soup)
li_list=soup.select('div.mw-parser-output > ul> li')
for title in li_list:
    print(title.a.string)
    lis=title.select('ul > li')
    for li in lis:
        print(url3+li.a['href'])
        print('-',li.a.string)
# Out:
# 하늘과 바람과 별과 시
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%84%9C%EC%8B%9C
# - 서시
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%9E%90%ED%99%94%EC%83%81
# - 자화상
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%86%8C%EB%85%84
# - 소년
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%88%88_%EC%98%A4%EB%8A%94_%EC%A7%80%EB%8F%84
# - 눈 오는 지도
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%8F%8C%EC%95%84%EC%99%80_%EB%B3%B4%EB%8A%94_%EB%B0%A4
# - 돌아와 보는 밤
# https://ko.wikisource.org/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EB%B3%91%EC%9B%90
# - 병원
# ...

# %%
def content(url):
    res=urlopen(url)
    soup=bs(res,'html.parser')
    cont=soup.select('div.mw-parser-output > div > p')
    if len(cont)>0:
        print(cont[0].text)

# %%
res2=urlopen('https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC') # 인코딩 16진수 자동으로 됨
soup=bs(res2,'html.parser')
url3='https://ko.wikisource.org'
#print(soup)
li_list=soup.select('div.mw-parser-output > ul> li')
for title in li_list:
    print(title.a.string)
    lis=title.select('ul > li')
    if len(lis)>0:
        for li in lis:
            print('-',li.a.string)
            content(url3+li.a['href'])
    else:
        #content(url3+li.a['href'])
# Out:
#   File "<ipython-input-28-1f178a1c8416>", line 14
#     #content(url3+li.a['href'])
#                                ^
# SyntaxError: unexpected EOF while parsing
